# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
import igraph as ig
import numpy as np
import chart_studio
#import chart_studio.tools as tls
chart_studio.tools.set_credentials_file(username='bengieru', api_key='aEWAksFu2EImuQ4jxWut')

# %%
layers = 3
nodes = 10
n = layers*nodes
intra_edges = [(i,i+1) for i in range(9)] +[(9,0)]+ [(i,i+1) for i in range(10,19)] +[(19,10)]+ [(i,i+1) for i in range(20,29)] + [(29,20)]
inter_edges = [(i,i+nodes) for i in range(nodes)] + [(nodes+i,nodes*2+i) for i in range(nodes)]

# %%
x1_coords = [np.sin(2*np.pi*i*(1/nodes)) for i in range(nodes*layers)]
y1_coords = [0 for i in range(nodes)] + [1 for i in range(nodes)] + [2 for i in range(nodes)]
z1_coords = [np.cos(2*np.pi*i*(1/nodes)) for i in range(nodes*layers)]

x11_edges = []
y11_edges = []
z11_edges = []
for e in intra_edges:
    x11_edges+=[x1_coords[e[0]], x1_coords[e[1]], None]# x-coordinates of edge ends
    y11_edges+=[y1_coords[e[0]], y1_coords[e[1]], None]# y-coordinates edges ends
    z11_edges+=[z1_coords[e[0]], z1_coords[e[1]], None]
    
x21_edges = []
y21_edges = []
z21_edges = []
for e in intra_edges:
    x21_edges+=[x1_coords[e[0]], x1_coords[e[1]], None]# x-coordinates of edge ends
    y21_edges+=[y1_coords[e[0]], y1_coords[e[1]], None]
    z21_edges+=[z1_coords[e[0]], z1_coords[e[1]], None]

# %%
x2_coords = [3+np.sin(2*np.pi*i*(1/nodes)) for i in range(nodes*layers)]
y2_coords = [0 for i in range(nodes)] + [1 for i in range(nodes)] + [2 for i in range(nodes)]
z2_coords = [3+np.cos(2*np.pi*i*(1/nodes)) for i in range(nodes*layers)]

x12_edges = []
y12_edges = []
z12_edges = []
for e in intra_edges:
    x12_edges+=[x2_coords[e[0]], x2_coords[e[1]], None]# x-coordinates of edge ends
    y12_edges+=[y2_coords[e[0]], y2_coords[e[1]], None]# y-coordinates edges ends
    z12_edges+=[z2_coords[e[0]], z2_coords[e[1]], None]
    
x22_edges = []
y22_edges = []
z22_edges = []
for e in intra_edges:
    x22_edges+=[x2_coords[e[0]], x2_coords[e[1]], None]# x-coordinates of edge ends
    y22_edges+=[y2_coords[e[0]], y2_coords[e[1]], None]
    z22_edges+=[z2_coords[e[0]], z2_coords[e[1]], None]

# %%
trace1=go.Scatter3d(x=x11_edges,
               y=y11_edges,
               z=z11_edges,
               mode='lines',
               line=dict(color='rgb(25,25,225)', width=5),
               hoverinfo='none'
               )
trace2=go.Scatter3d(x=x21_edges,
               y=y21_edges,
               z=z21_edges,
               mode='lines',
               line=dict(color='rgb(225,25,25)', width=5),
               hoverinfo='none'
               )

trace3=go.Scatter3d(x=x1_coords,
               y=y1_coords,
               z=z1_coords,
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size=6,
                             color=group,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             ),
               #text=labels,
               hoverinfo='text'
               )

trace4=go.Scatter3d(x=x12_edges,
               y=y12_edges,
               z=z12_edges,
               mode='lines',
               line=dict(color='rgb(25,25,225)', width=5),
               hoverinfo='none'
               )
trace5=go.Scatter3d(x=x22_edges,
               y=y22_edges,
               z=z22_edges,
               mode='lines',
               line=dict(color='rgb(225,25,25)', width=5),
               hoverinfo='none'
               )

trace6=go.Scatter3d(x=x2_coords,
               y=y2_coords,
               z=z2_coords,
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size=6,
                             color=group,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             ),
               #text=labels,
               hoverinfo='text'
               )



axis=dict(showbackground=True,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = go.Layout(
         #title="Network of coappearances of characters in Victor Hugo's novel<br> Les Miserables (3D visualization)",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            #text="Data source: <a href='http://bost.ocks.org/mike/miserables/miserables.json'>[1] miserables.json</a>",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )

# %%
data=[trace1, trace2, trace3, trace4, trace5, trace6]
fig=go.Figure(data=data, layout=layout)

py.iplot(fig, filename='tunnel')
# Out:
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="https://plotly.com/~bengieru/130.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
nt = 50
nv = 50
a = -2
h = 2
r = 1/2
theta = np.linspace(0, 2*np.pi, nt)
v = np.linspace(a, a+h, nv )
theta, v = np.meshgrid(theta, v)
x1 = r*np.cos(theta)
y1 = v
z1 = r*np.sin(theta)

h = 10
theta = np.linspace(0, 2*np.pi, nt)
v = np.linspace(a, a+h, nv )
theta, v = np.meshgrid(theta, v)
x2 = r*np.cos(theta)
y2 = 1/(1+np.exp(-10*v))
z2 = r*np.sin(theta) + 1/(1+np.exp(-10*v))

surface1 = go.Surface(x=x1, y=y1, z=z1)
surface2 = go.Surface(x=x2, y=y2, z=z2)
data = [surface1] + [surface2]

fig = go.Figure(data=data)
fig.show()
#py.iplot(fig, filename='cylinder?')
# Out:
# <div>                            <div id="f762a08c-fb11-4b97-a730-1b9afce8e345" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f762a08c-fb11-4b97-a730-1b9afce8e345")) {                    Plotly.newPlot(                        "f762a08c-fb11-4b97-a730-1b9afce8e345",                        [{"type": "surface", "x": [[0.5, 0.4958950069116231, 0.4836474315195147, 0.4634583786730109, 0.4356593520616947, 0.40070681093397836, 0.3591746750488638, 0.3117449009293668, 0.2591962841552626, 0.20239167156119697, 0.14226379331551633, 0.07979994751668965, 0.016025788785827666, -0.048011512953840776, -0.11126046697815717, -0.17268252721065375, -0.23126914512041755, -0.2860583300610847, -0.3361504451306582, -0.3807229791845671, -0.4190440524459202, -0.4504844339512
# ...
